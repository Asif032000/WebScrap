# %% [markdown]
# <a href="https://colab.research.google.com/github/Asif032000/WebScrap/blob/master/Day2Scrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing modules
from bs4 import BeautifulSoup
import requests #replacement of urllib
import time # to give delay msg

# %%
#taking corona live dataset
url = "https://www.worldometers.info/coronavirus/"
#connecting with http protocol
htmlpage = requests.get(url)
purehtmlpage = htmlpage.content
soup = BeautifulSoup(purehtmlpage, 'html5lib') #souping

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
tb = soup.find_all('table',class_="table table-bordered table-hover main_table_countries")
print(tb)
# Out:
# [<table class="table table-bordered table-hover main_table_countries" id="main_table_countries_today" style="width:100%">
#                     <thead>
#                         <tr>
#                             <th width="100">Country,<br/>Other</th>
#                             <th width="20">Total<br/>Cases</th>
#                             <th width="30">New<br/>Cases</th>
#                             <th width="30">Total<br/>Deaths</th>
#                             <th width="30">New<br/>Deaths</th>
#                             <th width="30">Total<br/>Recovered</th>
#                             <th width="30">Active<br/>Cases</th>
#                             <th width="30">Serious,<br/>Critical</th>
#                             <th width="30">Tot Cases/<br/>1M pop</th>
#                             <th width="30">Tot Deaths/<br/>1M pop</th>
#                         </tr>
#                     </thead>
#                     <tbody>
# ...

# %%
#finding all table rows
for trr in tb[0].find_all('tr'):
  for rows in trr.find_all('th'):
    print(rows.text)
# Out:
# Country,Other
# TotalCases
# NewCases
# TotalDeaths
# NewDeaths
# TotalRecovered
# ActiveCases
# Serious,Critical
# Tot Cases/1M pop
# Tot Deaths/1M pop

# %%
#scraping data for each row with normal country data
for trr1 in tb[0].find_all('tr'):
  for rows in trr1.find_all('td'):
    print(rows.text)
# Out:
# China
# 81,340
# +55
# 3,292
# +5
# 74,588
# 3,460
# 1,034
# 57
# 2
# USA
# 85,740
# +305
# 1,303
# +8
# 1,868
# 82,569
# 2,122
# 259
# 4
# Italy
# 80,589
#
# 8,215
#
# 10,361
# 62,013
# 3,612
# 1,333
# 136
# Spain
# 57,786
#
# 4,365
#
# 7,015
# 46,406
# 3,166
# 1,236
# 93
# Germany
# 47,278
# +3,340
# 281
# +14
# 5,673
# 41,324
# 23
# 564
# 3
# Iran
# 32,332
# +2,926
# 2,378
# +144
# 11,133
# 18,821
# 2,893
# 385
# 28
# France
# 29,155
#
# 1,696
#
# 4,948
# 22,511
# 3,375
# 447
# 26
# Switzerland
# 11,951
# +140
# 197
# +5
# 131
# 11,623
# 203
# 1,381
# 23
# UK
# 11,658
#
# 578
#
# 135
# 10,945
# 163
# 172
# 9
# S. Korea
# 9,332
# +91
# 139
# +8
# 4,528
# 4,665
# 59
# 182
# 3
# Netherlands
# 7,431
#
# 434
#
# 3
# 6,994
# 761
# 434
# 25
# Belgium
# 7,284
# +1,049
# 289
# +69
# 858
# 6,137
# 690
# 628
# 25
# Austria
# 7,196
# +287
# 58
# +9
# 225
# 6,913
# 96
# 799
# 6
# Canada
# 4,043
#
# 39
#
# 228
# 3,776
# 120
# 107
# 1
# Turkey
# 3,629
#
# 75
#
# 26
# 3,528
# 136
# 43
# 0.9
# ...
